# %% [markdown]
# <a href="https://colab.research.google.com/github/minwww111/-1/blob/main/%EC%A0%84%EA%B8%B0%EC%84%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install supabase
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 kB 10.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.15
#     Uninstalling aiohttp-3.11.15:
#       Successfully uninstalled aiohttp-3.11.15
# ...

# %%
# !pip install git+https://github.com/supabase-community/supabase-py.git
# Out:
# ...
#   Cloning https://github.com/supabase-community/supabase-py.git to /tmp/pip-req-build-jtw6ztk7
#   Running command git clone --filter=blob:none --quiet https://github.com/supabase-community/supabase-py.git /tmp/pip-req-build-jtw6ztk7
#   Resolved https://github.com/supabase-community/supabase-py.git to commit c8e6132acc52f97979616c020aa2852a02cac39b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from supabase import create_client, Client

url = "https://gqgirsmyynnwzwytcziw.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImdxZ2lyc215eW5ud3p3eXRjeml3Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc0NzU5MTgyNCwiZXhwIjoyMDYzMTY3ODI0fQ.jwAdkkgI4_jOEWhfMtQw9ApajyQHNThaDdVQW_Yaty0"  # ← 당신의 Anon 또는 Service Role 키

supabase: Client = create_client(url, key)

response = supabase.table("전기세").select("*").execute()
data = response.data
print(data)
# Out:
# [{'자치구': '강남구', '연도': 2022.01, '사용료': 85546.78}, {'자치구': '강남구', '연도': 2022.02, '사용료': 79971.54439}, {'자치구': '강남구', '연도': 2022.03, '사용료': 69322.6714}, {'자치구': '강남구', '연도': 2022.04, '사용료': 64490.63635}, {'자치구': '강남구', '연도': 2022.05, '사용료': 68981.73424}, {'자치구': '강남구', '연도': 2022.06, '사용료': 77466.06631}, {'자치구': '강남구', '연도': 2022.07, '사용료': 121298.4267}, {'자치구': '강남구', '연도': 2022.08, '사용료': 137855.6032}, {'자치구': '강남구', '연도': 2022.09, '사용료': 95461.01119}, {'자치구': '강남구', '연도': 2022.1, '사용료': 78869.57908}, {'자치구': '강남구', '연도': 2022.11, '사용료': 79675.36565}, {'자치구': '강남구', '연도': 2022.12, '사용료': 91016.74015}, {'자치구': '강남구', '연도': 2023.01, '사용료': 106576.2736}, {'자치구': '강남구', '연도': 2023.02, '사용료': 99746.90126}, {'자치구': '강남구', '연도': 2023.03, '사용료': 84800.15456}, {'자치구': '강남구', '연도': 2023.04, '사용료': 83604.90982}, {'자치구': '강남구', '연도': 2023.05, '사용료': 83139.32783}, {'자치구': '강남구', '연도': 2023.06, '사용료': 102328.6398}, {'자치구': '강남구', '연도': 2023.07, '사용료': 140908.2394}, {'자치구': '강남구', '연도': 2023.08, '사용
# ...

# %%
from supabase import create_client, Client

#Supabase 프로젝트 정보,
url = "https://gqgirsmyynnwzwytcziw.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImdxZ2lyc215eW5ud3p3eXRjeml3Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc0NzU5MTgyNCwiZXhwIjoyMDYzMTY3ODI0fQ.jwAdkkgI4_jOEWhfMtQw9ApajyQHNThaDdVQW_Yaty0"

#클라이언트 생성,
supabase: Client = create_client(url, key)

#테이블에서 데이터 가져오기,
response = supabase.table("전기세").select("*").execute()

#데이터 출력,
data = response.data
print(data)
# Out:
# [{'자치구': '강남구', '연도': 2022.01, '사용료': 85546.78}, {'자치구': '강남구', '연도': 2022.02, '사용료': 79971.54439}, {'자치구': '강남구', '연도': 2022.03, '사용료': 69322.6714}, {'자치구': '강남구', '연도': 2022.04, '사용료': 64490.63635}, {'자치구': '강남구', '연도': 2022.05, '사용료': 68981.73424}, {'자치구': '강남구', '연도': 2022.06, '사용료': 77466.06631}, {'자치구': '강남구', '연도': 2022.07, '사용료': 121298.4267}, {'자치구': '강남구', '연도': 2022.08, '사용료': 137855.6032}, {'자치구': '강남구', '연도': 2022.09, '사용료': 95461.01119}, {'자치구': '강남구', '연도': 2022.1, '사용료': 78869.57908}, {'자치구': '강남구', '연도': 2022.11, '사용료': 79675.36565}, {'자치구': '강남구', '연도': 2022.12, '사용료': 91016.74015}, {'자치구': '강남구', '연도': 2023.01, '사용료': 106576.2736}, {'자치구': '강남구', '연도': 2023.02, '사용료': 99746.90126}, {'자치구': '강남구', '연도': 2023.03, '사용료': 84800.15456}, {'자치구': '강남구', '연도': 2023.04, '사용료': 83604.90982}, {'자치구': '강남구', '연도': 2023.05, '사용료': 83139.32783}, {'자치구': '강남구', '연도': 2023.06, '사용료': 102328.6398}, {'자치구': '강남구', '연도': 2023.07, '사용료': 140908.2394}, {'자치구': '강남구', '연도': 2023.08, '사용
# ...
